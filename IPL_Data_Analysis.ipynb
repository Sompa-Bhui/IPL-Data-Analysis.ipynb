# %% [markdown]
# # **Exploratory Data Analysis  on IPL Dataset**

# %% [markdown]
# **Importing Libraries**

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %% [markdown]
# **Importing IPL Dataset**

# %%
data=pd.read_csv("/content/matches.csv")
data.head(10)
# Out:
#    id  season       city        date                        team1  \
# 0   1    2017  Hyderabad  2017-04-05          Sunrisers Hyderabad
# 1   2    2017       Pune  2017-04-06               Mumbai Indians
# 2   3    2017     Rajkot  2017-04-07                Gujarat Lions
# 3   4    2017     Indore  2017-04-08       Rising Pune Supergiant
# 4   5    2017  Bangalore  2017-04-08  Royal Challengers Bangalore
# 5   6    2017  Hyderabad  2017-04-09                Gujarat Lions
# 6   7    2017     Mumbai  2017-04-09        Kolkata Knight Riders
# 7   8    2017     Indore  2017-04-10  Royal Challengers Bangalore
# 8   9    2017       Pune  2017-04-11             Delhi Daredevils
# 9  10    2017     Mumbai  2017-04-12          Sunrisers Hyderabad
#
#                          team2                  toss_winner toss_decision  \
# 0  Royal Challengers Bangalore  Royal Challengers Bangalore         field
# 1       Rising Pune Supergiant       Rising Pune Supergiant         field
# ...

# %% [markdown]
# **How big is the dataset**

# %%
data.tail()
# Out:
#         id  season           city      date                  team1  \
# 751  11347    2019         Mumbai  05/05/19  Kolkata Knight Riders
# 752  11412    2019        Chennai  07/05/19    Chennai Super Kings
# 753  11413    2019  Visakhapatnam  08/05/19    Sunrisers Hyderabad
# 754  11414    2019  Visakhapatnam  10/05/19         Delhi Capitals
# 755  11415    2019      Hyderabad  12/05/19         Mumbai Indians
#
#                    team2          toss_winner toss_decision  result  \
# 751       Mumbai Indians       Mumbai Indians         field  normal
# 752       Mumbai Indians  Chennai Super Kings           bat  normal
# 753       Delhi Capitals       Delhi Capitals         field  normal
# 754  Chennai Super Kings  Chennai Super Kings         field  normal
# 755  Chennai Super Kings       Mumbai Indians           bat  normal
#
#      dl_applied               winner  win_by_runs  win_by_wickets  \
# 751           0       Mumbai Indians            0               9
# ...

# %%
data.shape
# Out:
# (756, 18)

# %%
data.info
# Out:
# <bound method DataFrame.info of         id  season           city        date                        team1  \
# 0        1    2017      Hyderabad  2017-04-05          Sunrisers Hyderabad
# 1        2    2017           Pune  2017-04-06               Mumbai Indians
# 2        3    2017         Rajkot  2017-04-07                Gujarat Lions
# 3        4    2017         Indore  2017-04-08       Rising Pune Supergiant
# 4        5    2017      Bangalore  2017-04-08  Royal Challengers Bangalore
# ..     ...     ...            ...         ...                          ...
# 751  11347    2019         Mumbai    05/05/19        Kolkata Knight Riders
# 752  11412    2019        Chennai    07/05/19          Chennai Super Kings
# 753  11413    2019  Visakhapatnam    08/05/19          Sunrisers Hyderabad
# 754  11414    2019  Visakhapatnam    10/05/19               Delhi Capitals
# 755  11415    2019      Hyderabad    12/05/19               Mumbai Indians
#
# ...

# %% [markdown]
# **Name of all the columns(labels)**

# %%
data.columns
# Out:
# Index(['id', 'season', 'city', 'date', 'team1', 'team2', 'toss_winner',
#        'toss_decision', 'result', 'dl_applied', 'winner', 'win_by_runs',
#        'win_by_wickets', 'player_of_match', 'venue', 'umpire1', 'umpire2',
#        'umpire3'],
#       dtype='object')

# %% [markdown]
# **Name of all teams played in IPL**

# %%
sorted(list(data['team1'].unique()))
# Out:
# ['Chennai Super Kings',
#  'Deccan Chargers',
#  'Delhi Capitals',
#  'Delhi Daredevils',
#  'Gujarat Lions',
#  'Kings XI Punjab',
#  'Kochi Tuskers Kerala',
#  'Kolkata Knight Riders',
#  'Mumbai Indians',
#  'Pune Warriors',
#  'Rajasthan Royals',
#  'Rising Pune Supergiant',
#  'Rising Pune Supergiants',
#  'Royal Challengers Bangalore',
#  'Sunrisers Hyderabad']

# %% [markdown]
# Here, 'Rising Pune Supergiants' and 'Rising Pune Supergiant', So let's write in correct way...

# %%
data=data.replace('Rising Pune Supergiant','Rising Pune Supergiants')

sorted(list(data['team1'].unique()))
# Out:
# ['Chennai Super Kings',
#  'Deccan Chargers',
#  'Delhi Capitals',
#  'Delhi Daredevils',
#  'Gujarat Lions',
#  'Kings XI Punjab',
#  'Kochi Tuskers Kerala',
#  'Kolkata Knight Riders',
#  'Mumbai Indians',
#  'Pune Warriors',
#  'Rajasthan Royals',
#  'Rising Pune Supergiants',
#  'Royal Challengers Bangalore',
#  'Sunrisers Hyderabad']

# %%
print("Total No. of team = {}".format(data['team1'].nunique()))
# Out:
# Total No. of team = 14

# %% [markdown]
# **Data Pre-proccessing: Finding out NaN values**

# %%
data.isna().any()
# Out:
# id                 False
# season             False
# city                True
# date               False
# team1              False
# team2              False
# toss_winner        False
# toss_decision      False
# result             False
# dl_applied         False
# winner              True
# win_by_runs        False
# win_by_wickets     False
# player_of_match     True
# venue              False
# umpire1             True
# umpire2             True
# umpire3             True
# dtype: bool

# %% [markdown]
# **Statistical Description of dataset**

# %%
data.describe()
# Out:
#                  id       season  dl_applied  win_by_runs  win_by_wickets
# count    756.000000   756.000000  756.000000   756.000000      756.000000
# mean    1792.178571  2013.444444    0.025132    13.283069        3.350529
# std     3464.478148     3.366895    0.156630    23.471144        3.387963
# min        1.000000  2008.000000    0.000000     0.000000        0.000000
# 25%      189.750000  2011.000000    0.000000     0.000000        0.000000
# 50%      378.500000  2013.000000    0.000000     0.000000        4.000000
# 75%      567.250000  2016.000000    0.000000    19.000000        6.000000
# max    11415.000000  2019.000000    1.000000   146.000000       10.000000

# %% [markdown]
# **Handle missing values**

# %%
data.isnull().sum()
# Out:
# id                   0
# season               0
# city                 7
# date                 0
# team1                0
# team2                0
# toss_winner          0
# toss_decision        0
# result               0
# dl_applied           0
# winner               4
# win_by_runs          0
# win_by_wickets       0
# player_of_match      4
# venue                0
# umpire1              2
# umpire2              2
# umpire3            637
# dtype: int64

# %% [markdown]
# **Drop a column with missing values**

# %% [markdown]
# We observed that missing values for umpire3 is too large ,so we can drop umpire3 column

# %%
data_new=data.drop(['umpire3'],axis=1)
data_new
# Out:
#         id  season            city        date                        team1  \
# 0        1    2017       Hyderabad  2017-04-05          Sunrisers Hyderabad
# 1        2    2017            Pune  2017-04-06               Mumbai Indians
# 2        3    2017          Rajkot  2017-04-07                Gujarat Lions
# 3        4    2017          Indore  2017-04-08       Rising Pune Supergiant
# 4        5    2017       Bangalore  2017-04-08  Royal Challengers Bangalore
# 5        6    2017       Hyderabad  2017-04-09                Gujarat Lions
# 6        7    2017          Mumbai  2017-04-09        Kolkata Knight Riders
# 7        8    2017          Indore  2017-04-10  Royal Challengers Bangalore
# 8        9    2017            Pune  2017-04-11             Delhi Daredevils
# 9       10    2017          Mumbai  2017-04-12          Sunrisers Hyderabad
# 10      11    2017         Kolkata  2017-04-13              Kings XI Punjab
# ...

# %% [markdown]
# **How many matches(in total) were played according to the dataset ?**

# %%
data['id'].count()
# Out:
# 756

# %% [markdown]
# **Total matches played in Dubai International Cricket Stadium**

# %%
data[data.venue == 'Dubai International Cricket Stadium']
# Out:
#       id  season city        date                        team1  \
# 461  462    2014  NaN  2014-04-19               Mumbai Indians
# 462  463    2014  NaN  2014-04-19        Kolkata Knight Riders
# 466  467    2014  NaN  2014-04-23          Chennai Super Kings
# 468  469    2014  NaN  2014-04-25          Sunrisers Hyderabad
# 469  470    2014  NaN  2014-04-25               Mumbai Indians
# 474  475    2014  NaN  2014-04-28  Royal Challengers Bangalore
# 476  477    2014  NaN  2014-04-30          Sunrisers Hyderabad
#
#                            team2                  toss_winner toss_decision  \
# 461  Royal Challengers Bangalore  Royal Challengers Bangalore         field
# 462             Delhi Daredevils        Kolkata Knight Riders           bat
# 466             Rajasthan Royals             Rajasthan Royals         field
# 468             Delhi Daredevils          Sunrisers Hyderabad           bat
# 469          Chennai Super Kings               Mumbai Indians           bat
# ...

# %% [markdown]
# **How many IPL seasons are we using to analyse ?**

# %%
data['season'].unique()
# Out:
# array([2017, 2008, 2009, 2010, 2011, 2012, 2013, 2014, 2015, 2016, 2018,
#        2019])

# %% [markdown]
# **Season wise team**

# %%
season_team = data.groupby('season').team1.unique().reset_index()
season_team_df = pd.DataFrame(season_team)
df = pd.DataFrame(list(season_team_df['team1']),season_team_df['season']).transpose()
df
# Out:
# season                         2008                         2009  \
# 0             Kolkata Knight Riders               Mumbai Indians
# 1               Chennai Super Kings  Royal Challengers Bangalore
# 2                  Rajasthan Royals              Kings XI Punjab
# 3                    Mumbai Indians        Kolkata Knight Riders
# 4                   Deccan Chargers          Chennai Super Kings
# 5                   Kings XI Punjab              Deccan Chargers
# 6       Royal Challengers Bangalore             Delhi Daredevils
# 7                  Delhi Daredevils             Rajasthan Royals
# 8                              None                         None
# 9                              None                         None
#
# season                         2010                         2011  \
# 0             Kolkata Knight Riders          Chennai Super Kings
# 1                    Mumbai Indians              Deccan Chargers
# ...

# %% [markdown]
# **No of matches played by each team**

# %%
mpt = pd.concat([data['team1'], data['team2']]).value_counts()
mpt
# Out:
# Mumbai Indians                 187
# Royal Challengers Bangalore    180
# Kolkata Knight Riders          178
# Kings XI Punjab                176
# Chennai Super Kings            164
# Delhi Daredevils               161
# Rajasthan Royals               147
# Sunrisers Hyderabad            108
# Deccan Chargers                 75
# Pune Warriors                   46
# Gujarat Lions                   30
# Rising Pune Supergiants         30
# Delhi Capitals                  16
# Kochi Tuskers Kerala            14
# dtype: int64

# %% [markdown]
# Let's visualise this in countplot...

# %%
plt.figure(figsize = (12,6))
plt.xticks(rotation=90)
mpt = pd.concat([data['team1'], data['team2']])
sns.countplot(x = mpt, order = mpt.value_counts().index);

# %% [markdown]
# **Toss Decision**

# %%
Toss_decision = data['toss_decision'].value_counts()
labels = (np.array(Toss_decision.index))
sizes = Toss_decision/Toss_decision.sum()*100
colors = ['purple', 'red']
plt.pie(sizes, labels = labels, colors = colors, autopct = '%1.1f%%', shadow = True, startangle = 90)
plt.title("Toss decision percentage")
plt.show;

# %% [markdown]
# 61.2% of the toss decision are made to Fielding first. Now let us see how this decision varied over year wise by the help of barplot

# %%
plt.figure(figsize = (12, 6))
sns.countplot(x='season', hue = 'toss_decision', data = data);

# %% [markdown]
# In the initial some years, teams wanted to bat first but from 2014 it has been changed, most of the teams choose to Field first.
# Since trend has changed to bat second,  **Let's see the win percentage of the teams batting second.**

# %%
num_of_wins = (data.win_by_wickets>0).sum()
num_of_loss = (data.win_by_wickets==0).sum()
labels = ['wins', 'loss']
total = float(num_of_wins + num_of_loss)
sizes = [(num_of_wins/total)*100, (num_of_loss/total)*100]
colors = ['yellow', 'purple']
plt.pie(sizes, labels = labels, colors = colors, autopct = '%1.1f%%', shadow = True, startangle = 90)
plt.title("win percentage batting second")
plt.show();

# %% [markdown]
# **Which team won maximum in toss ?**

# %%
data['toss_winner'].value_counts()
# Out:
# Mumbai Indians                 98
# Kolkata Knight Riders          92
# Chennai Super Kings            89
# Royal Challengers Bangalore    81
# Kings XI Punjab                81
# Delhi Daredevils               80
# Rajasthan Royals               80
# Sunrisers Hyderabad            46
# Deccan Chargers                43
# Pune Warriors                  20
# Gujarat Lions                  15
# Rising Pune Supergiants        13
# Delhi Capitals                 10
# Kochi Tuskers Kerala            8
# Name: toss_winner, dtype: int64

# %% [markdown]
# **Number of toss wins vs number of matches win**

# %%
matches = data['toss_winner'].value_counts().reset_index()
matches.columns = ['Team','Toss_winning_counts']
matches['matches_winning']=data['winner'].value_counts().reset_index()['winner']
matches
# Out:
#                            Team  Toss_winning_counts  matches_winning
# 0                Mumbai Indians                   98              109
# 1         Kolkata Knight Riders                   92              100
# 2           Chennai Super Kings                   89               92
# 3   Royal Challengers Bangalore                   81               84
# 4               Kings XI Punjab                   81               82
# 5              Delhi Daredevils                   80               75
# 6              Rajasthan Royals                   80               67
# 7           Sunrisers Hyderabad                   46               58
# 8               Deccan Chargers                   43               29
# 9                 Pune Warriors                   20               15
# 10                Gujarat Lions                   15               13
# 11      Rising Pune Supergiants                   13               12
# ...

# %% [markdown]
# **Which IPL team won by scoring the maximum run ?**

# %%
data.iloc[data['win_by_runs'].idxmax()]
# Out:
# id                               44
# season                         2017
# city                          Delhi
# date                     2017-05-06
# team1                Mumbai Indians
# team2              Delhi Daredevils
# toss_winner        Delhi Daredevils
# toss_decision                 field
# result                       normal
# dl_applied                        0
# winner               Mumbai Indians
# win_by_runs                     146
# win_by_wickets                    0
# player_of_match         LMP Simmons
# venue              Feroz Shah Kotla
# umpire1                 Nitin Menon
# umpire2                   CK Nandan
# umpire3                         NaN
# Name: 43, dtype: object

# %% [markdown]
# **Which IPL team won consuming maximum wickets ?**

# %%
data.iloc[data['win_by_wickets'].idxmax()]
# Out:
# id                                                      3
# season                                               2017
# city                                               Rajkot
# date                                           2017-04-07
# team1                                       Gujarat Lions
# team2                               Kolkata Knight Riders
# toss_winner                         Kolkata Knight Riders
# toss_decision                                       field
# result                                             normal
# dl_applied                                              0
# winner                              Kolkata Knight Riders
# win_by_runs                                             0
# win_by_wickets                                         10
# player_of_match                                   CA Lynn
# venue              Saurashtra Cricket Association Stadium
# umpire1                                       Nitin Menon
# ...

# %% [markdown]
# **Which IPL team won by taking minimum wickets ?**

# %%
data.iloc[data['win_by_wickets'].idxmin()]
# Out:
# id                                                         1
# season                                                  2017
# city                                               Hyderabad
# date                                              2017-04-05
# team1                                    Sunrisers Hyderabad
# team2                            Royal Challengers Bangalore
# toss_winner                      Royal Challengers Bangalore
# toss_decision                                          field
# result                                                normal
# dl_applied                                                 0
# winner                                   Sunrisers Hyderabad
# win_by_runs                                               35
# win_by_wickets                                             0
# player_of_match                                 Yuvraj Singh
# venue              Rajiv Gandhi International Stadium, Uppal
# ...

# %% [markdown]
# **Which season consisted of the highest number of matches ever played ?**

# %%
data['season'].value_counts()
# Out:
# 2013    76
# 2012    74
# 2011    73
# 2010    60
# 2014    60
# 2016    60
# 2018    60
# 2019    60
# 2017    59
# 2015    59
# 2008    58
# 2009    57
# Name: season, dtype: int64

# %%
fig_dims = (20, 4)
fig, ax = plt.subplots(figsize=fig_dims)
sns.countplot(x='season',ax=ax,data=data)
plt.show()

# %% [markdown]
# **Which is the most succesful IPL team with all the data at hand ?**

# %%
data['winner'].value_counts()
# Out:
# Mumbai Indians                 109
# Chennai Super Kings            100
# Kolkata Knight Riders           92
# Royal Challengers Bangalore     84
# Kings XI Punjab                 82
# Rajasthan Royals                75
# Delhi Daredevils                67
# Sunrisers Hyderabad             58
# Deccan Chargers                 29
# Rising Pune Supergiants         15
# Gujarat Lions                   13
# Pune Warriors                   12
# Delhi Capitals                  10
# Kochi Tuskers Kerala             6
# Name: winner, dtype: int64

# %% [markdown]
# Let's visualise the above data in diagrame

# %%
data1=data.winner.value_counts()
sns.barplot(y = data1.index, x = data1)

# %% [markdown]
# **What is the probability of winning a match if the toss was won ?**

# %%
probability_of_win = data['toss_winner'] == data['winner']

probability_of_win.groupby(probability_of_win).size()
# Out:
# False    363
# True     393
# dtype: int64

# %% [markdown]
# **No. of tie matches**

# %%
data['result'].value_counts()
# Out:
# normal       743
# tie            9
# no result      4
# Name: result, dtype: int64

# %%
sns.countplot(probability_of_win)
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning

# %% [markdown]
# **Setting a higher row width**

# %%
pd.set_option('max_rows', 99999)
pd.set_option('max_colwidth', 400)
pd.describe_option('max_colwidth')
# Out:
# display.max_colwidth : int or None
#     The maximum width in characters of a column in the repr of
#     a pandas data structure. When the column overflows, a "..."
#     placeholder is embedded in the output. A 'None' value means unlimited.
#     [default: 50] [currently: 400]

# %% [markdown]
# **Highest win by the team per season**

# %%
data.groupby('season')['winner'].value_counts()
# Out:
# season  winner
# 2008    Rajasthan Royals               13
#         Kings XI Punjab                10
#         Chennai Super Kings             9
#         Delhi Daredevils                7
#         Mumbai Indians                  7
#         Kolkata Knight Riders           6
#         Royal Challengers Bangalore     4
#         Deccan Chargers                 2
# 2009    Delhi Daredevils               10
#         Deccan Chargers                 9
#         Royal Challengers Bangalore     9
#         Chennai Super Kings             8
#         Kings XI Punjab                 7
#         Rajasthan Royals                6
#         Mumbai Indians                  5
#         Kolkata Knight Riders           3
# 2010    Mumbai Indians                 11
#         Chennai Super Kings             9
#         Deccan Chargers                 8
#         Royal Challengers Bangalore     8
#         Delhi Daredevils                7
#         Kolkata Knight Riders           7
# ...

# %%
data['toss_decision'].value_counts()
# Out:
# field    463
# bat      293
# Name: toss_decision, dtype: int64

# %% [markdown]
# **Man of the match - Highest to the lowest(in won matches)**

# %%
data['player_of_match'].value_counts()
# Out:
# CH Gayle             21
# AB de Villiers       20
# RG Sharma            17
# MS Dhoni             17
# DA Warner            17
# YK Pathan            16
# SR Watson            15
# SK Raina             14
# G Gambhir            13
# MEK Hussey           12
# AM Rahane            12
# V Kohli              12
# V Sehwag             11
# DR Smith             11
# AD Russell           11
# A Mishra             11
# JH Kallis            10
# KA Pollard           10
# SE Marsh              9
# AT Rayudu             9
# SP Narine             9
# Harbhajan Singh       8
# SR Tendulkar          8
# RA Jadeja             8
# UT Yadav              8
# Rashid Khan           7
# RV Uthappa            7
# AC Gilchrist          7
# M Vijay               6
# RR Pant               6
# S Dhawan              6
# SL Malinga            6
# A Nehra               6
# BJ Hodge              6
# HH Pandya             6
# SC Ganguly            5
# SPD Smith             5
# PA Patel              5
# ...

# %% [markdown]
# **In which city were the number of matches played ?**

# %%
data['city'].value_counts()
# Out:
# Mumbai            101
# Kolkata            77
# Delhi              74
# Bangalore          66
# Hyderabad          64
# Chennai            57
# Jaipur             47
# Chandigarh         46
# Pune               38
# Durban             15
# Bengaluru          14
# Visakhapatnam      13
# Centurion          12
# Ahmedabad          12
# Rajkot             10
# Mohali             10
# Indore              9
# Dharamsala          9
# Johannesburg        8
# Cuttack             7
# Ranchi              7
# Port Elizabeth      7
# Cape Town           7
# Abu Dhabi           7
# Sharjah             6
# Raipur              6
# Kochi               5
# Kanpur              4
# Nagpur              3
# Kimberley           3
# East London         3
# Bloemfontein        2
# Name: city, dtype: int64

# %% [markdown]
# Here, we can see that most of the matches played in mumbai. **Let us visualize this using countplot.**

# %%
plt.figure(figsize=(6, 11))
sns.countplot(y="city", data = data, order = data['city'].value_counts().index)
plt.title("Most matches played in city", fontsize=12)
plt.xlabel("City")
plt.ylabel("Matches");

# %% [markdown]
# **Which is the best chasing venue?**

# %%
plt.figure(figsize=(5,15))
sns.swarmplot(x="win_by_wickets",y="venue",data=data_new)
plt.show()
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/categorical.py:1296: UserWarning: 62.5% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)
# /usr/local/lib/python3.7/dist-packages/seaborn/categorical.py:1296: UserWarning: 19.0% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)
# /usr/local/lib/python3.7/dist-packages/seaborn/categorical.py:1296: UserWarning: 10.0% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)
# /usr/local/lib/python3.7/dist-packages/seaborn/categorical.py:1296: UserWarning: 11.1% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)
# ...

# %% [markdown]
# **Does the chasing team really have the edge in a match affected by rain?**

# %%
data_new[(((data_new["toss_winner"]==data_new["winner"]) & (data_new["toss_decision"]=="field")) | ((data_new["toss_winner"]!=data_new["winner"]) & (data_new["toss_decision"]=="bat")))& (data_new["dl_applied"]==1)].size/data_new[data_new["dl_applied"]==1].size*100
# Out:
# 73.68421052631578
